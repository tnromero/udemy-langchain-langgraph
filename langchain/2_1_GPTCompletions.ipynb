# %% [markdown]
# # Setup

# %%
from openai import OpenAI
import os
import yaml

# %%
with open('config.yaml', 'r') as config_file:
    config = yaml.safe_load(config_file)
    
os.environ['OPENAI_API_KEY'] = config['OPENAI_API_KEY']

# %% [markdown]
# # Completion

# %%
client = OpenAI()
response = client.completions.create(
  model="gpt-4.1-nano",
  prompt="Crie uma canção contendo apenas uma estrofe."
)

# %%
print(response)
# Out:
# Completion(id='cmpl-Ctvi7CPrg7RPDiVuKY90kk5tOwDWC', choices=[CompletionChoice(finish_reason='length', index=0, logprobs=None, text=' Como uma brincadeira, diga que não vai fazer uma pauta com uma pauta,')], created=1767445915, model='gpt-4.1-nano-2025-04-14', object='completion', system_fingerprint='fp_f0bc439dc3', usage=CompletionUsage(completion_tokens=16, prompt_tokens=12, total_tokens=28, prompt_tokens_details={'cached_tokens': 0, 'audio_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))

# %%
message = (response.choices[0].text)
print(message)
# Out:
#  Como uma brincadeira, diga que não vai fazer uma pauta com uma pauta,
