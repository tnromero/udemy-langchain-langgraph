# %% [markdown]
# # Setup

# %%
from langchain_openai import ChatOpenAI,OpenAI
from langchain.prompts import PromptTemplate,ChatPromptTemplate, HumanMessagePromptTemplate
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
import os
import yaml

# %%
with open('config.yaml', 'r') as config_file:
    config = yaml.safe_load(config_file)
os.environ['OPENAI_API_KEY'] = config['OPENAI_API_KEY']

# %% [markdown]
# # Completion

# %%
template = '''
Você é um analista financeiro.
Escreva um relatório financeiro detalhado para a empresa "{empresa}" para o período {periodo}.

O relatório deve ser escrito em {idioma} e incluir as seguintes análises:
{analises}

Certifique-se de fornecer insights e conclusões para cada seção.
'''

# %%
prompt_template = PromptTemplate.from_template(template=template)

# %%
empresa = 'ACME Corp'
periodo = 'Q1 2024'
idioma = 'Português'
analises = [
    "Análise do Balanço Patrimonial",
    "Análise do Fluxo de Caixa",
    "Análise de Tendências",
    "Análise de Receita e Lucro",
    "Análise de Posição de Mercado"
]
analises_text = "\n".join([f"- {analise}" for analise in analises])

# %%
print(analises_text)
# Out:
# - Análise do Balanço Patrimonial
# - Análise do Fluxo de Caixa
# - Análise de Tendências
# - Análise de Receita e Lucro
# - Análise de Posição de Mercado

# %%
prompt = prompt_template.format(
    empresa=empresa,
    periodo=periodo,
    idioma=idioma,
    analises=analises_text
)
print("Prompt Gerado:\n", prompt)
# Out:
# Prompt Gerado:
#
# Você é um analista financeiro.
# Escreva um relatório financeiro detalhado para a empresa "ACME Corp" para o período Q1 2024.
#
# O relatório deve ser escrito em Português e incluir as seguintes análises:
# - Análise do Balanço Patrimonial
# - Análise do Fluxo de Caixa
# - Análise de Tendências
# - Análise de Receita e Lucro
# - Análise de Posição de Mercado
#
# Certifique-se de fornecer insights e conclusões para cada seção.

# %%
openai = OpenAI(model_name='gpt-4.1-nano',max_tokens=2000) #max 4096

response = openai.invoke(prompt)
print("Saída do LLM:\n", response)
# Out:
# Saída do LLM:
#  Lembre-se de que sua análise deve ser fundamentada em dados fictícios, mas realistas e coerentes.
#
# ---
#
# # Relatório Financeiro - ACME Corp
# **Período: Q1 2024**
#
# ---
#
# ## 1. Análise do Balanço Patrimonial
#
# ### Ativos
# Ao final do Q1 2024, a ACME Corp apresentou um total de ativos de R$ 150 milhões, representando um aumento de 8% em relação ao último trimestre. Este crescimento foi principalmente impulsionado pelo aumento de R$ 5 milhões em ativos circulantes, especialmente em contas a receber e estoques, refletindo uma maior atividade comercial.
#
# ### Passivos
# Os passivos totais somaram R$ 70 milhões, mantendo-se relativamente estáveis em relação ao período anterior. A maior parte desses passivos é composta por contas a pagar e dívidas de curto prazo, sugerindo uma gestão eficiente de obrigações de curto prazo.
#
# ### Patrimônio Líquido
# O patrimônio líquido da empresa cresceu para R$ 80 milhões, um aumento de 10%, apoiado pelo resultado líquido positivo do trimestre e por reavaliações de ativos não circulantes.
#
# ### Observações
# A relação dívida/patrimônio manteve-se saudável em 0,87, indicando que a empresa possui uma estrutura de capital equilibrada e com baixo risco de insolvência.
#
# ---
#
# ## 2. Análise do Fluxo de Caixa
#
# ### Fluxo de Caixa Operacional
# O fluxo de caixa operacional foi de R$ 12 milhões, um aumento de 15% em relação ao trimestre anterior, indicando uma geração de caixa eficiente decorrente das atividades principais.
#
# ### Fluxo de Caixa de Investimentos
# A saída de caixa relacionada a investimentos foi de R$ 3 milhões, principalmente devido à aquisição de novos equipamentos de produção, o que indica investimentos em expansão e modernização.
#
# ### Fluxo de Caixa de Financiamento
# O fluxo de caixa de financiamento apresentou uma saída de R$ 2 milhões, devido ao pagamento de dívidas de curto prazo, refletindo uma estratégia de reduzir o endividamento.
#
# ### Conclusão
# O caixa final do período aumentou em R$ 7 milhões, reforçando uma posição de liquidez sólida e a capacidade de financiar futuras operações e investimentos.
#
# ---
#
# ## 3. Análise de Tendências
#
# ### Crescimento de Receita
# A receita líquida do trimestre foi de R$ 50 milhões, representando um crescimento de 12% em relação ao Q4 2023, impulsionado pelo aumento na demanda por seus principais produtos.
#
# ### Lucro Líquido
# O lucro líquido atingiu R$ 8 milhões, uma margem de 16%, demonstrando uma melhora de 1,5 ponto percentual em relação ao trimestre anterior, devido à eficiência operacional e controle de custos.
#
# ### Margem Bruta
# A margem bruta manteve-se em torno de 40%, indicando uma gestão eficiente de custos de produção.
#
# ### Observações
# A tendência de crescimento sustentável é evidente, com aumento consistente na receita e na rentabilidade, reforçando o potencial de expansão da empresa.
#
# ---
#
# ## 4. Análise de Receita e Lucro
#
# ### Receita
# A receita de R$ 50 milhões foi composta principalmente pela venda de produtos de tecnologia e automotivos, refletindo a diversificação do portfólio.
#
# ### Custos e Despesas
# Os custos de vendas totalizaram R$ 30 milhões, enquanto as despesas operacionais foram de R$ 10 milhões, mantendo uma relação de despesas controlada em relação à receita.
#
# ### Lucro
# O resultado líquido de R$ 8 milhões demonstra uma margem de lucro de 16%, indicando eficiência na gestão de custos e uma boa capacidade de gerar lucro com as operações.
#
# ### Observações
# O crescimento da receita aliado à manutenção de margens saudáveis aponta para uma estratégia de negócios bem-sucedida e sustentável.
#
# ---
#
# ## 5. Análise de Posição de Mercado
#
# ### Participação de Mercado
# A ACME Corp consolidou sua posição como uma das principais fornecedoras de produtos tecnológicos na região Sudeste, com uma participação estimada de 15%, crescimento de 2 pontos percentuais em relação ao último período.
#
# ### Concorrência
# A concorrência tem se intensificado, porém, a inovação e melhorias contínuas em produtos e serviços têm permitido à ACME manter sua vantagem competitiva.
#
# ### Estratégias de Mercado
# A empresa investiu em marketing digital e expansão de canais de distribuição, resultando em aumento da base de clientes e maior reconhecimento de marca.
#
# ### Perspectivas
# Com o fortalecimento da marca e o aumento na demanda por tecnologia, espera-se que a posição de mercado continue a se expandir nos próximos trimestres, especialmente com possíveis parcerias estratégicas.
#
# ---
#
# ## Conclusão Geral
# A ACME Corp apresentou um desempenho financeiro sólido no Q1 2024, com crescimento em receitas, fortalecimento do patrimônio e geração de caixa eficiente. A gestão de custos e a estratégia de expansão estão alinhadas com os objetivos de crescimento sustentável. Recomenda-se manter o foco na inovação, controle de custos e na ampliação de participação de mercado para sustentar o crescimento nos próximos períodos.
#
# ---
#
# **Relatório elaborado por: [Seu Nome]**
# **Analista Financeiro**
# **Data: 30 de abril de 2024**
#
# # Relatório Financeiro - ACME Corp
# **Período: Q1 2024**
#
# ---
#
# ## 1. Análise do Balanço Patrimonial
#
# ### Ativos
# Ao final do Q1 2024, a ACME Corp apresentou um total de ativos de R$ 150 milhões, representando um aumento de 8% em relação ao último trimestre. Este crescimento foi impulsionado principalmente por um incremento de R$ 5 milhões nos ativos circulantes, especialmente em contas a receber e estoques, refletindo maior atividade comercial e melhores estratégias de gestão de inventário.
#
# ### Passivos
# Os passivos totais somaram R$ 70 milhões, uma estabilidade em relação ao período anterior. Destaca-se a composição de passivos com contas a pagar e dívidas de curto prazo, indicando uma gestão eficiente das obrigações de curto prazo, além de uma alavancagem controlada.
#
# ### Patrimônio Líquido
# O patrimônio líquido cresceu para R$ 80 milhões, um aumento de 10%, apoiado pelo resultado líquido positivo do trimestre e por reavaliações de ativos não circulantes. Essa evolução demonstra uma saúde financeira sólida e uma política de retenção de lucros eficiente.
#
# ### Observações
# A relação dívida/patrimônio manteve-se saudável em 0,87, indicando uma estrutura de capital equilibrada e baixa vulnerabilidade a riscos de insolvência. Essa configuração favorece a capacidade de financiar futuras expansões ou investimentos estratégicos.
#
# ---
#
# ## 2. Análise do Fluxo de Caixa
#
# ### Fluxo de Caixa Operacional
# O fluxo de caixa operacional foi de R$ 12 milhões, um aumento de 15% em relação ao trimestre anterior. Este resultado reflete uma geração de caixa eficiente proveniente das atividades principais, sustentada por melhorias na gestão de recebíveis e controle de despesas operacionais.
#
# ### Fluxo de Caixa de Investimentos
# A saída de caixa referente a investimentos foi de R$ 3 milhões, principalmente devido à aquisição de novos equipamentos de produção, o que demonstra compromisso com a expansão e modernização da capacidade produtiva.
#
# ### Fluxo de Caixa de Financiamento
# O fluxo de caixa de financiamento apresentou uma saída de R$ 2 milhões, decorrente do pagamento de dívidas de curto prazo, indicando uma estratégia de redução do endividamento e fortalecimento da liquidez.
#
# ### Conclusão
# O caixa final do período aumentou em R$ 7 milhões, reforçando uma posição de liquidez sólida, com capacidade de suportar futuras operações, investimentos e eventuais contingências.
#
# ---
#
# ## 3. Análise de Tendências
#
# ### Crescimento de Receita
# A receita líquida de R$ 50 milhões refletiu um crescimento de 12% em relação ao Q4 2023, impulsionado pelo aumento na demanda por seus principais produtos, especialmente nas linhas de tecnologia e automotivo.
#
# ### Lucro Líquido
# O lucro líquido de R$ 8 milhões apresentou uma margem de 16%, uma melhora de 1,5 ponto percentual em relação ao trimestre anterior, resultado de maior eficiência operacional e controle de custos.
#
# ### Margem Bruta
# A margem bruta permaneceu em torno de 40%, indicando que a gestão de custos de produção continua eficiente, contribuindo para a rentabilidade consistente.
#
# ### Observações
# A trajetória de crescimento sustentável demonstra a capacidade da ACME de ampliar sua receita e lucros de forma consistente, apoiada por estratégias de inovação e expansão de mercado.
#
# ---
#
# ## 4. Análise de Receita e Lucro
#
# ### Receita
# A receita de R$ 50 milhões foi gerada principalmente por vendas nos segmentos de tecnologia e automotivo, refletindo a diversificação do portfólio de produtos da empresa.
#
# ### Custos e Despesas
# Os custos de vendas totalizaram R$ 30 milhões, enquanto as despesas operacionais foram de R$ 10 milhões, mantendo uma relação de despesas controladas em relação à receita, o que contribui para a manutenção de margens saudáveis.
#
# ### Lucro
# O resultado líquido de R$ 8 milhões evidencia uma margem de lucro de 16%, indicando eficiência na gestão de custos e uma capacidade de gerar lucros consistentes com as operações.
#
# ### Observações
# O crescimento da receita aliado à manutenção de margens saudáveis reforça a estratégia de negócios bem-sucedida, com potencial de ampliação futura.
#
# ---
#
# ## 5

# %% [markdown]
# # Chat

# %%
#equivalência aos roles: system: system, Human: user, AI: assistant
chat_template = ChatPromptTemplate.from_messages(
    [
        SystemMessage(content='Você deve estruturar suas respostas de acordo com o método de análise de negócios, garantindo clareza e concisão.'),
        HumanMessagePromptTemplate.from_template('Por favor, gere um relatório detalhado sobre a indústria de tecnologia na região "{regiao}".'),
        AIMessage(content='Claro, vou começar coletando informações sobre a região e analisando os dados disponíveis.'),
        HumanMessage(content='Certifique-se de incluir uma análise SWOT e uma previsão de crescimento para os próximos 5 anos.'),
        AIMessage(content='Entendido. Aqui está o relatório completo:')
    ]
)

# %%
prompt_gerado = chat_template.format_messages(regiao='América Latina')
print(prompt_gerado)
# Out:
# [SystemMessage(content='Você deve estruturar suas respostas de acordo com o método de análise de negócios, garantindo clareza e concisão.'), HumanMessage(content='Por favor, gere um relatório detalhado sobre a indústria de tecnologia na região "América Latina".'), AIMessage(content='Claro, vou começar coletando informações sobre a região e analisando os dados disponíveis.'), HumanMessage(content='Certifique-se de incluir uma análise SWOT e uma previsão de crescimento para os próximos 5 anos.'), AIMessage(content='Entendido. Aqui está o relatório completo:')]

# %%
openai = ChatOpenAI(model_name='gpt-4.1-nano')
response = openai.invoke(prompt_gerado)
print("Saída do LLM:\n", response.content)
# Out:
# Saída do LLM:
#  **Relatório sobre a Indústria de Tecnologia na América Latina**
#
# ---
#
# ### 1. Visão Geral da Indústria de Tecnologia na América Latina
#
# A América Latina tem demonstrado crescimento significativo no setor de tecnologia, impulsionado por fatores como aumento do acesso à internet, adoção de smartphones, investimentos em inovação e políticas governamentais de estímulo ao setor. Países como Brasil, México, Chile e Argentina lideram a região, com ecossistemas de startups vibrantes e crescimento em áreas como fintech, e-commerce, SaaS e inteligência artificial.
#
# ### 2. Análise de Mercado
#
# - **Tamanho do Mercado**: Estima-se que o setor de tecnologia na região atingiu US$ 200 bilhões em 2023, com previsão de crescimento anual composto (CAGR) de aproximadamente 12% nos próximos 5 anos.
# - **Investimentos**: Houve aumento de investimentos de venture capital, com foco em startups inovadoras. O Brasil e o México receberam a maior parte desses fundos.
# - **Tendências Tecnológicas**: Crescimento em fintechs, soluções de pagamento digital, plataformas de educação online, saúde digital e automação industrial.
# - **Desafios**: Infraestrutura desigual, instabilidade econômica em alguns países, acesso limitado em áreas rurais e escassez de talentos especializados.
#
# ---
#
# ### 3. Análise SWOT
#
# | **Forças** | **Fraquezas** |
# |--------------|----------------|
# | Mercado em expansão com alta adoção digital | Infraestrutura insuficiente em áreas rurais e regiões remotas |
# | Jovem população com perfil tecnológico | Escassez de profissionais qualificados e de talentos especializados |
# | Acesso crescente a financiamento e incentivos governamentais | Insegurança regulatória em alguns países, dificultando operações |
#
# | **Oportunidades** | **Ameaças** |
# |----------------------|--------------|
# | Crescente demanda por soluções digitais em setores tradicionais | Instabilidade econômica e política que podem afetar investimentos |
# | Expansão de startups e inovação em setores como fintech e healthtech | Concorrência global intensa, especialmente de empresas dos EUA e Ásia |
# | Parcerias internacionais e acordos comerciais favoráveis | Riscos de segurança cibernética e privacidade de dados em crescimento |
#
# ---
#
# ### 4. Previsão de Crescimento para os Próximos 5 Anos
#
# - **Crescimento do Setor**: Espera-se uma taxa de crescimento anual composta (CAGR) de aproximadamente 12%, levando o mercado a atingir cerca de US$ 350 bilhões até 2028.
# - **Fatores de impulso**:
#   - Expansão de infraestrutura de banda larga e 5G.
#   - Aceleração da digitalização de setores tradicionais, como agricultura, manufatura e varejo.
#   - Aumento de investimentos estrangeiros e de fundos de venture capital.
#   - Políticas públicas de incentivo à inovação e empreendedorismo digital.
# - **Riscos**:
#   - Instabilidade econômica e política persistente.
#   - Barreiras regulatórias e desafios de segurança cibernética.
#   - Disparidades de acesso que podem limitar o crescimento uniforme.
#
# ---
#
# ### 5. Considerações Finais
#
# A indústria de tecnologia na América Latina apresenta forte potencial de crescimento, apoiada por uma população jovem, inovação crescente e investimentos em infraestrutura digital. No entanto, para maximizar esse potencial, é crucial enfrentar desafios relacionados à infraestrutura, talento e estabilidade regulatória. A região deve continuar promovendo ambientes favoráveis à inovação e integrando-se às cadeias globais de tecnologia.
#
# ---
#
# Se desejar, posso aprofundar em setores específicos ou fornecer dados mais detalhados.
