# %% [markdown]
# # Setup

# %%
from langchain_openai import OpenAI
from langchain.prompts import PromptTemplate
import yaml
import os

# %%
with open('config.yaml', 'r') as config_file:
    config = yaml.safe_load(config_file)
os.environ['OPENAI_API_KEY'] = config['OPENAI_API_KEY']

# %%
openai = OpenAI(model_name='gpt-4.1-nano', temperature=0)

# %% [markdown]
# # Simple

# %%
prompt_template = PromptTemplate.from_template("Descreva as tendências tecnológicas em {ano}.")
runnable_sequence = prompt_template | openai
output = runnable_sequence.invoke({"ano": "2024"})

# %%
print("Output:\n", output)
# Out:
# Output:
#   Como elas podem impactar diferentes setores?**
#
# ### 4. **Questões de Opinião e Debate**
# - **Você acha que a inteligência artificial substituirá completamente os empregos humanos? Por quê?**
# - **Qual é o impacto das redes sociais na saúde mental dos jovens?**
# - **De que forma a educação deve evoluir para preparar melhor os estudantes para o futuro?**
#
# ### 5. **Questões de Cultura e Sociedade**
# - **Como a diversidade cultural enriquece uma sociedade?**
# - **Quais são os principais desafios enfrentados pelos movimentos de direitos civis atualmente?**
# - **De que maneira a arte influencia a sociedade?**
#
# ### 6. **Questões de Saúde e Bem-estar**
# - **Quais são as principais estratégias para manter uma boa saúde mental?**
# - **Como a tecnologia pode ajudar na gestão de doenças crônicas?**
# - **Quais hábitos de vida podem prevenir doenças cardiovasculares?**
#
# ### 7. **Questões de Educação**
# - **Qual é o papel da tecnologia na educação moderna?**
# - **Como as escolas podem promover a inclusão de estudantes com diferentes necessidades?**
# - **Quais habilidades são mais importantes para os estudantes do século XXI?**
#
# ### 8. **Questões de Ét
