# %% [markdown]
# # Setpup

# %%
from langchain_openai import OpenAI, ChatOpenAI
import os
import yaml

# %%
with open('config.yaml', 'r') as config_file:
    config = yaml.safe_load(config_file)
    
os.environ['OPENAI_API_KEY'] = config['OPENAI_API_KEY']

# %% [markdown]
# # Completion

# %%
openai = OpenAI(model_name="gpt-4.1-nano")
frequency_penalty = 1
presence_penalty = 1
temperature = 1
max_tokens = 500
n = 1
seed = 123
response = openai.invoke(
    input="Quem foi Carl Sagan?",
    temperature=temperature,
    frequency_penalty=frequency_penalty,
    presence_penalty=presence_penalty,
    max_tokens=max_tokens,
    n=n,
    seed=seed,
)
print(response)
# Out:
#  O que fez de tão importante na ciência?*
#
# **Caption:**
# Nascido em 1934, Carl Sagan foi um astrofísico e divulgador científico americano. Conhecido por popularizar a astronomia, ele ajudou a trazer o universo para as nossas casas através de livros, programas de televisão e palestras acessíveis a todos. Sua missão era inspirar curiosidade e esperança no futuro da humanidade explorando o cosmos.
#
# ---
#
# ### Post 2: As Contribuições Científicas
# *Texto:*
# Carl Sagan não apenas pensava sobre o universo — ele contribuiu ativamente para desvendá-lo. Ele trabalhou com planetologia, estudou atmosferas de outros planetas e foi fundamental na elaboração do programa Voyager, que enviou sondas ao espaço em busca de respostas sobre nosso sistema solar. Seu trabalho ampliou nossa compreensão do universo e deixou um legado científico duradouro.
#
# **Caption:**
# Vamos explorar alguns marcos na carreira de Carl Sagan:
# - Estudo das atmosferas nos planetas externos;
# - Participação no projeto Voyager;
# - Pesquisa sobre condições para vida além da Terra.
# Seu talento ajudou a ampliar os limites do conhecimento humano!
#
# ---
#
# ### Post 3: O Mestre da Divulgação Científica
# *Texto:*
# Além da pesquisa, Carl Sagan se destacou como comunicador excepcional. Com seu livro *Cosmos* e sua série televisiva homônima, traduziu conceitos complexos do universo para uma audiência global — despertando imaginação e paixão pela ciência. Ele acreditava que entender nosso lugar no cosmos é vital para nossa sobrevivência.
#
# **Caption:**
# Você conhece *Cosmos*, o famoso programa apresentado por Carl Sagan? ��✨ Foi graças à sua arte em explicar temas difíceis com simplicidade que milhões se apaixonaram pelo espaço! Sua abordagem humanizadora continua inspirando gerações até hoje.
#
# ---
#
# ### Post 4: Os Valores Fundamentais
# *Texto:*
# Sagan também nos lembrou dos valores essenciais na prática científica — ceticismo saudável, honestidade intelectual e esperança contínua. Para ele, questionar tudo era fundamental para progresso; acreditar sem evidências é perigoso demais quando se trata do futuro da humanidade.
#
# **Caption:**
# "Extraia toda certeza," dizia Sagan ��✨ Essa frase reforça sua ideia central: dúvida criativa leva ao conhecimento verdadeiro! Como você pode aplicar essa postura na sua rotina diária?
#
# ---
#
# ### Post 5:

# %% [markdown]
# # Chat

# %%
openai = ChatOpenAI(model_name='gpt-4.1-nano')
messages = [
    {"role": "system", "content": "Você é um assistente que fornece informações sobre figuras históricas."},
    {"role": "user", "content": "Quem foi Carl Sagan?"}
]
response = openai.invoke(messages)
print(response)
# Out:
# content='Carl Sagan foi um renomado astrônomo, astrofísico, cosmólogo, autor e divulgador científico norte-americano. Nascido em 9 de novembro de 1934, em Brooklyn, Nova York, e falecido em 20 de dezembro de 1996, Sagan é amplamente conhecido por seu papel na popularização da ciência e por seu trabalho na busca por vida extraterrestre.\n\nEle foi um dos principais responsáveis pelo programa de televisão "Cosmos: A Personal Voyage" (1980), que ajudou a tornar a ciência acessível e fascinante para o público em geral. Além disso, Sagan contribuiu significativamente para a pesquisa sobre a atmosfera de Marte, a existência de planetas fora do sistema solar e a possibilidade de vida em outros mundos. \n\nAutor de vários livros, incluindo "Cosmos", "Contato" e "O Mundo Assombrado pelos Demônios", sua obra combina rigor científico com uma abordagem poética e filosófica. Sagan também foi um defensor do pensamento crítico, da pesquisa científica e da responsabilidade social e ambiental.\n\nSua influência permanece até hoje, inspirando gerações a explorar o universo e buscar o conhecimento com curiosidade e ceticismo saudável.' response_metadata={'token_usage': {'completion_tokens': 249, 'prompt_tokens': 30, 'total_tokens': 279, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_f0bc439dc3', 'finish_reason': 'stop', 'logprobs': None} id='run-0ff0e312-efb0-4254-8205-57720c8d5440-0' usage_metadata={'input_tokens': 30, 'output_tokens': 249, 'total_tokens': 279}

# %%
print(response.content)
# Out:
# Carl Sagan foi um renomado astrônomo, astrofísico, cosmólogo, autor e divulgador científico norte-americano. Nascido em 9 de novembro de 1934, em Brooklyn, Nova York, e falecido em 20 de dezembro de 1996, Sagan é amplamente conhecido por seu papel na popularização da ciência e por seu trabalho na busca por vida extraterrestre.
#
# Ele foi um dos principais responsáveis pelo programa de televisão "Cosmos: A Personal Voyage" (1980), que ajudou a tornar a ciência acessível e fascinante para o público em geral. Além disso, Sagan contribuiu significativamente para a pesquisa sobre a atmosfera de Marte, a existência de planetas fora do sistema solar e a possibilidade de vida em outros mundos.
#
# Autor de vários livros, incluindo "Cosmos", "Contato" e "O Mundo Assombrado pelos Demônios", sua obra combina rigor científico com uma abordagem poética e filosófica. Sagan também foi um defensor do pensamento crítico, da pesquisa científica e da responsabilidade social e ambiental.
#
# Sua influência permanece até hoje, inspirando gerações a explorar o universo e buscar o conhecimento com curiosidade e ceticismo saudável.
