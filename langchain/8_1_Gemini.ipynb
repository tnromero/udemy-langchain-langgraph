# %% [markdown]
# # Setup

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
import os
import yaml

# %%
with open('config.yaml', 'r') as config_file:
    config = yaml.safe_load(config_file)
os.environ['GOOGLE_API_KEY'] = config['GOOGLE_API_KEY']

googleai = ChatGoogleGenerativeAI(model='gemini-2.5-flash')

# %%
template = """
Você é um analista financeiro.
Escreva um relatório financeiro detalhado para a empresa "{empresa}" para o período {periodo}.

O relatório deve ser escrito em {idioma} e incluir as seguintes análises:
{analises}

Certifique-se de fornecer insights e conclusões para cada seção.
"""

# %%
prompt_template = PromptTemplate.from_template(template=template)

# %%
empresa = 'ACME Corp'
periodo = 'Q1 2024'
idioma = 'Português'
analises = [
    "Análise do Balanço Patrimonial",
    "Análise do Fluxo de Caixa",
    "Análise de Tendências",
    "Análise de Receita e Lucro",
    "Análise de Posição de Mercado"
]
analises_text = "\n".join([f"- {analise}" for analise in analises])

# %%
prompt = prompt_template.format(
    empresa=empresa,
    periodo=periodo,
    idioma=idioma,
    analises=analises_text
)

# %%
response = googleai.invoke(prompt)
print("Relatório Financeiro:\n", response.content)
# Out:
# Relatório Financeiro:
#  ## Relatório Financeiro Detalhado - ACME Corp
# ### Período: Q1 2024
#
# **Para:** Conselho de Administração, Equipe de Liderança Sênior
# **De:** Analista Financeiro
# **Data:** 25 de Abril de 2024
# **Assunto:** Análise de Desempenho Financeiro do Primeiro Trimestre de 2024 (Q1 2024)
#
# ---
#
# ### 1. Introdução
#
# Este relatório apresenta uma análise financeira detalhada da ACME Corp para o primeiro trimestre encerrado em 31 de março de 2024. O objetivo é fornecer uma visão abrangente do desempenho financeiro da empresa, sua posição atual e as tendências observadas, com base nos demonstrativos financeiros (Balanço Patrimonial, Demonstração de Resultados e Demonstração de Fluxos de Caixa). Serão abordadas as principais métricas e indicadores para oferecer insights estratégicos e conclusões acionáveis.
#
# ---
#
# ### 2. Análise do Balanço Patrimonial
#
# O Balanço Patrimonial da ACME Corp em 31 de março de 2024 reflete uma posição financeira robusta e crescente, com melhorias notáveis em liquidez e capitalização.
#
# **Principais Destaques (Q1 2024 vs. Q4 2023):**
#
# *   **Ativos Circulantes:**
#     *   **Caixa e Equivalentes de Caixa:** Aumentaram significativamente de R$ 45 milhões (Q4 2023) para R$ 58 milhões (Q1 2024), demonstrando forte geração de caixa operacional e gestão eficiente do capital.
#     *   **Contas a Receber:** Cresceram de R$ 30 milhões para R$ 35 milhões, em linha com o aumento das vendas, indicando um ciclo de vendas saudável, mas exigindo monitoramento da qualidade dos recebíveis.
#     *   **Estoques:** Mantiveram-se relativamente estáveis em R$ 22 milhões, sugerindo uma boa gestão de inventário em relação ao volume de vendas.
# *   **Ativos Não Circulantes:**
#     *   **Imobilizado (Líquido):** Aumentou ligeiramente de R$ 120 milhões para R$ 125 milhões, refletindo investimentos contínuos em CAPEX para expansão ou modernização de ativos.
#     *   **Ativos Intangíveis:** Estáveis em R$ 15 milhões, indicando que não houve grandes aquisições ou baixas significativas de intangíveis no trimestre.
# *   **Passivos Circulantes:**
#     *   **Contas a Pagar:** Aumentaram de R$ 20 milhões para R$ 24 milhões, o que pode ser um reflexo do aumento das operações e compras, sem indicar problemas de liquidez.
#     *   **Dívida de Curto Prazo:** Permaneceu estável em R$ 10 milhões, demonstrando que a empresa não recorreu a novos endividamentos de curto prazo.
# *   **Passivos Não Circulantes:**
#     *   **Dívida de Longo Prazo:** Estável em R$ 40 milhões, indicando uma gestão prudente do endividamento de longo prazo.
# *   **Patrimônio Líquido:**
#     *   Cresceu de R$ 162 milhões (Q4 2023) para R$ 176 milhões (Q1 2024), impulsionado principalmente pelo lucro líquido do período, reforçando a solidez financeira e a capacidade de autofinanciamento da empresa.
#
# **Insights:**
# A ACME Corp apresenta uma estrutura de balanço patrimonial saudável. A melhoria na posição de caixa e o crescimento do patrimônio líquido são indicadores positivos de liquidez e solvência. A gestão de ativos circulantes parece equilibrada, com crescimento de recebíveis alinhado às vendas e estoques sob controle.
#
# **Conclusão:**
# A posição do Balanço Patrimonial da ACME Corp no Q1 2024 é forte. A empresa demonstra excelente liquidez e uma base de capital sólida, o que a posiciona bem para futuras oportunidades de crescimento e para enfrentar potenciais desafios econômicos. A capacidade de financiar o crescimento através de lucros retidos é um ponto de destaque.
#
# ---
#
# ### 3. Análise do Fluxo de Caixa
#
# A Demonstração de Fluxos de Caixa do Q1 2024 revela uma performance de caixa muito positiva, com forte geração operacional.
#
# **Principais Destaques (Q1 2024):**
#
# *   **Fluxo de Caixa das Atividades Operacionais (FCAO):**
#     *   Gerou R$ 18 milhões em caixa, um aumento significativo em relação ao Q1 2023 (R$ 12 milhões). Este valor é substancialmente maior que o lucro líquido, indicando que a ACME Corp está convertendo seus lucros em caixa de forma muito eficiente.
#     *   As principais contribuições vieram do lucro líquido ajustado por despesas não caixa (depreciação e amortização) e uma gestão eficaz do capital de giro, apesar do aumento das contas a receber.
# *   **Fluxo de Caixa das Atividades de Investimento (FCAI):**
#     *   Utilizou R$ 8 milhões, principalmente para aquisição de imobilizado (CAPEX). Isso está em linha com o aumento observado no balanço patrimonial e sinaliza investimentos estratégicos para suportar o crescimento futuro da empresa.
# *   **Fluxo de Caixa das Atividades de Financiamento (FCAF):**
#     *   Registrou uma saída de R$ 3 milhões, composta principalmente pelo pagamento de dividendos aos acionistas (R$ 2 milhões) e pequenas amortizações de dívida. Nenhuma nova dívida significativa foi emitida, o que reforça a capacidade de autofinanciamento.
# *   **Variação Líquida no Caixa:**
#     *   O saldo de caixa aumentou em R$ 7 milhões no trimestre (R$ 18M - R$ 8M - R$ 3M), corroborando o crescimento do caixa e equivalentes no balanço patrimonial.
#
# **Insights:**
# A ACME Corp demonstra uma excelente capacidade de geração de caixa a partir de suas operações principais. O FCAO forte permite à empresa financiar seus investimentos em crescimento (CAPEX) e remunerar seus acionistas (dividendos) sem depender excessivamente de financiamento externo.
#
# **Conclusão:**
# A saúde do fluxo de caixa da ACME Corp é exemplar. A robusta geração de caixa operacional é um pilar fundamental para a sustentabilidade e o crescimento da empresa, proporcionando flexibilidade financeira e reduzindo o risco.
#
# ---
#
# ### 4. Análise de Tendências
#
# A análise das tendências para o Q1 2024, comparada com períodos anteriores (Q1 2023 e Q4 2023), revela um padrão consistente de crescimento e melhoria.
#
# **Principais Tendências Observadas:**
#
# *   **Crescimento da Receita:** A receita tem mostrado uma trajetória ascendente consistente ano a ano e sequencialmente.
#     *   Q1 2023: R$ 95 milhões
#     *   Q4 2023: R$ 110 milhões
#     *   Q1 2024: R$ 125 milhões
#     *   Isso representa um crescimento de 31.6% YoY (Q1 2024 vs Q1 2023) e 13.6% QoQ (Q1 2024 vs Q4 2023).
# *   **Rentabilidade Crescente:** O lucro líquido e as margens têm melhorado.
#     *   Q1 2023 Lucro Líquido: R$ 8 milhões
#     *   Q4 2023 Lucro Líquido: R$ 10 milhões
#     *   Q1 2024 Lucro Líquido: R$ 14 milhões
#     *   A margem líquida também apresenta uma tendência de alta, indicando maior eficiência operacional e controle de custos.
# *   **Melhora da Liquidez:** O saldo de caixa e a liquidez corrente (ativos circulantes / passivos circulantes) têm se fortalecido progressivamente.
#     *   Liquidez Corrente Q1 2023: 1.8x
#     *   Liquidez Corrente Q4 2023: 2.1x
#     *   Liquidez Corrente Q1 2024: 2.3x
# *   **Estabilidade da Dívida:** A dívida total tem se mantido estável ou diminuído em relação ao patrimônio líquido e ao EBITDA, indicando uma gestão prudente do endividamento.
#     *   Dívida Líquida/EBITDA Q1 2023: 1.5x
#     *   Dívida Líquida/EBITDA Q4 2023: 1.2x
#     *   Dívida Líquida/EBITDA Q1 2024: 0.9x
#
# **Insights:**
# A ACME Corp não apenas cresce, mas o faz de maneira sustentável e com melhoria em suas métricas de eficiência e solidez. As tendências de crescimento de receita e lucro, combinadas com a gestão de dívida e o fortalecimento da liquidez, indicam uma empresa em excelente forma.
#
# **Conclusão:**
# As tendências financeiras da ACME Corp são extremamente positivas, demonstrando um crescimento robusto e consistente em todas as áreas-chave. A empresa está em uma trajetória de ascensão, consolidando sua posição e construindo uma base financeira cada vez mais sólida.
#
# ---
#
# ### 5. Análise de Receita e Lucro
#
# O desempenho da ACME Corp em termos de receita e lucro no Q1 2024 foi excepcional, superando as expectativas e demonstrando eficiência operacional.
#
# **Principais Destaques (Q1 2024):**
#
# *   **Receita Total:** R$ 125 milhões, representando um crescimento de 31.6% em relação ao Q1 2023 (R$ 95 milhões) e 13.6% em relação ao Q4 2023 (R$ 110 milhões).
#     *   O crescimento foi impulsionado principalmente pela expansão em novos mercados (mencionar se aplicável, e.g., "lançamento de novos produtos X e Y" ou "aumento da participação de mercado no segmento Z").
# *   **Custo dos Produtos Vendidos (CPV):** R$ 70 milhões.
# *   **Lucro Bruto:** R$ 55 milhões, resultando em uma Margem Bruta de 44% (vs. 42% no Q1 2023). A melhoria na margem bruta indica maior eficiência na produção ou melhor poder de precificação.
# *   **Despesas Operacionais:**
#     *   **Despesas com Vendas, Gerais e Administrativas (SG&A):** R$ 28 milhões. Embora tenha havido um aumento absoluto devido ao crescimento da empresa, a proporção em relação à receita diminuiu ligeiramente, indicando alavancagem operacional.
#     *   **Despesas com Pesquisa e Desenvolvimento (P&D):** R$ 5 milhões, demonstrando o compromisso contínuo com a inovação.
# *   **Lucro Operacional (EBIT):** R$ 22 milhões, com uma Margem Operacional de 17.6% (vs. 15.8% no Q1 2023).
# *   **Lucro Líquido:** R$ 14 milhões, resultando em uma Margem Líquida de 11.2% (vs. 8.4% no Q1 2023). O crescimento do lucro líquido foi de 75% em relação ao Q1 2023 (R$ 8 milhões).
# *   **Lucro Por Ação (LPA):** R$ 1.40 (assumindo 10 milhões de ações em circulação), um aumento considerável em relação aos R$ 0.80 do Q1 2023.
#
# **Insights:**
# A ACME Corp demonstrou uma capacidade notável de traduzir o crescimento da receita em um crescimento ainda mais robusto do lucro líquido. A expansão das margens bruta, operacional e líquida é um testemunho da gestão eficaz de custos, eficiência operacional e, possivelmente, do poder de precificação dos seus produtos/serviços.
#
# **Conclusão:**
# O desempenho de receita e lucro no Q1 2024 foi excepcional. A empresa não apenas está crescendo rapidamente, mas também está se tornando mais lucrativa e eficiente, o que é um sinal muito positivo para os investidores e para a sustentabilidade de longo prazo.
#
# ---
#
# ### 6. Análise de Posição de Mercado
#
# A ACME Corp consolidou e expandiu sua posição de mercado no Q1 2024, fortalecendo sua vantagem competitiva e reconhecimento de marca.
#
# **Principais Destaques:**
#
# *   **Participação de Mercado:** Estimamos um aumento na participação de mercado em nossos segmentos chave (e.g., "soluções de software B2B" ou "equipamentos industriais de alta tecnologia") de [X]% para [Y]% no Q1 2024, impulsionado pelo sucesso de [mencionar estratégia, e.g., "novos produtos", "expansão geográfica", "campanhas de marketing bem-sucedidas"].
# *   **Vantagem Competitiva:**
#     *   **Inovação:** O investimento contínuo em P&D (R$ 5 milhões no Q1 2024) tem resultado em produtos/serviços diferenciados que atendem às necessidades emergentes dos clientes.
#     *   **Qualidade e Serviço ao Cliente:** Relatos e feedback de clientes indicam alta satisfação, o que contribui para a fidelização e aquisição de novos clientes por meio de boca a boca.
#     *   **Marca:** A marca ACME Corp continua a ser reconhecida pela confiabilidade e inovação no mercado.
# *   **Ambiente Competitivo:** Apesar de um ambiente competitivo dinâmico com a presença de [mencionar concorrentes ou tipo de concorrência], a ACME Corp tem conseguido se destacar e ganhar terreno, demonstrando a resiliência de seu modelo de negócios.
# *   **Expansão Geográfica/Segmentos:** A empresa tem feito progressos na penetração de [mencionar novas regiões ou segmentos de clientes], o que contribui para a diversificação de suas fontes de receita.
#
# **Insights:**
# A ACME Corp não está apenas crescendo financeiramente, mas também fortalecendo ativamente sua posição estratégica no mercado. A combinação de inovação, qualidade e uma execução de mercado eficaz está permitindo à empresa superar a concorrência e aumentar sua relevância.
#
# **Conclusão:**
# A ACME Corp mantém uma posição de mercado forte e em crescimento, solidificada por sua capacidade de inovar, entregar valor ao cliente e executar estratégias de mercado eficazes. A empresa está bem posicionada para continuar a expandir sua influência e participação nos mercados em que atua.
#
# ---
#
# ### 7. Conclusão Geral e Recomendações
#
# O Q1 2024 foi um trimestre excepcional para a ACME Corp. A empresa demonstrou um crescimento de receita robusto, uma rentabilidade significativamente melhorada, uma geração de caixa forte e uma posição financeira sólida. Todas as tendências apontam para uma trajetória positiva e sustentável.
#
# **Pontos Fortes Resumidos:**
#
# *   **Crescimento Acelerado:** Receita e lucro líquido com crescimento de dois dígitos.
# *   **Eficiência Operacional:** Expansão de margens bruta e líquida.
# *   **Saúde Financeira:** Excelente liquidez, forte geração de caixa operacional e patrimônio líquido crescente.
# *   **Posição de Mercado:** Consolidação e expansão da participação, impulsionadas por inovação e qualidade.
#
# **Recomendações:**
#
# 1.  **Continuar Investindo em P&D:** Manter o ritmo de inovação é crucial para sustentar a vantagem competitiva e impulsionar o crescimento futuro.
# 2.  **Otimizar Capital de Giro:** Embora a gestão de capital de giro seja boa, continuar monitorando de perto Contas a Receber e Estoques para garantir que o crescimento não sobrecarregue a liquidez.
# 3.  **Explorar Oportunidades de Expansão:** Com a forte posição de caixa, a ACME Corp pode considerar oportunidades estratégicas de fusões e aquisições (M&A) ou expansão orgânica em novos mercados/segmentos.
# 4.  **Gerenciamento de Custos:** Continuar a buscar eficiências operacionais para sustentar a expansão das margens em um ambiente de custos potencialmente volátil.
# 5.  **Comunicar o Sucesso:** Compartilhar este desempenho positivo com investidores e stakeholders para fortalecer a confiança e o valor da empresa.
#
# Em suma, a ACME Corp está em uma excelente posição financeira e estratégica para o restante de 2024 e além. A equipe de gestão deve ser parabenizada pelo desempenho notável neste trimestre.
#
# ---
#
# **Isenção de Responsabilidade:** Este relatório é baseado em dados financeiros simulados e informações hipotéticas para fins de demonstração e análise. Não deve ser considerado como aconselhamento de investimento ou representação de uma empresa real. As projeções e as declarações prospectivas estão sujeitas a riscos e incertezas, e os resultados reais podem diferir materialmente.
